# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
print(model.encode("Hello").shape)
# Out:
# (384,)

# %%
import app as rag_system
print("FAISS vectors:", rag_system.vector_store.index.ntotal)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 import app as rag_system
# ----> 2 print("FAISS vectors:", rag_system.vector_store.index.ntotal)
#
# AttributeError: module 'app' has no attribute 'vector_store'
